# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from ipywidgets import interact

# %% [markdown]
# importing the data which saved in my drive

# %%
data= pd.read_csv('data.csv')

# %% [markdown]
# We have to optimize productivity
# by understanding requirements of climatic and soil condition for crops.
# Helps us to crope up with weather unpredictablity.

# %%
data.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
print("Shape of data", data.shape)
# Out:
# Shape of data (2200, 8)

# %% [markdown]
# To check Missing value in our data

# %%
data.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %% [markdown]
# Fill-NA function is used to replace these missing values with statistical values such as Mean,Median or Mode

# %% [markdown]
# NA means Not availabel

# %% [markdown]
# Pnadas have functions like fill_NA / drop-NA to treat missing values

# %% [markdown]
# to count unique values in colum we will use value_count() functions

# %%
data.head()
data['label'].value_counts()
# Out:
# watermelon     100
# pomegranate    100
# mungbean       100
# grapes         100
# papaya         100
# coconut        100
# cotton         100
# mango          100
# banana         100
# pigeonpeas     100
# mothbeans      100
# blackgram      100
# lentil         100
# orange         100
# kidneybeans    100
# coffee         100
# apple          100
# rice           100
# chickpea       100
# jute           100
# maize          100
# muskmelon      100
# Name: label, dtype: int64

# %%
print("Average Ratio for Nitrogen in the soil", format (data['N'].mean()))
print('Averafe ratio of phosphorous in the soil ', format (data['P'].mean()))
print('Avarage ratio of potassium in the soil', format(data['K'].mean()))
print("Avarage Temp in celcius", format(data['temperature'].mean()))
print('Average Humedity in %',format(data['humidity'].mean()))
print('Average PH of soil', format(data['ph'].mean()))
print('Average Rainfall in mm', format(data['rainfall'].mean()))
# Out:
# Average Ratio for Nitrogen in the soil 50.551818181818184
# Averafe ratio of phosphorous in the soil  53.36272727272727
# Avarage ratio of potassium in the soil 48.14909090909091
# Avarage Temp in celcius 25.616243851779533
# Average Humedity in % 71.48177921778648
# Average PH of soil 6.469480065256369
# Average Rainfall in mm 103.46365541576832

# %% [markdown]
# Here we are checking average climate conditions and soil requirements

# %%
# lets check the summary statistic for each crops


@interact
def summary(crops = list(data['label'].value_counts().index)):
    x= data[data['label']==crops]
    print('--------------------------------------------------------')
    print('Statistic of nitrogen')
    print('Min Nitrogen required :' ,x['N'].min())
    print('AVG Nitrogen required :' ,x['N'].mean())
    print('Max Nitrogen required :' ,x['N'].max())
    print('---------------------------------------------------------')
    print('Statistic of phosphorous')
    print('min of Phosphorous :' , x["P"].min())   
    print('Avg of Phosphorous :' , x["P"].mean())  
    print('Max of Phosphorous :' , x["P"].max()) 
    print('----------------------------------------------------------')
    print('Statistic of Potassium')
    print('Minimum Potassium required:', x['K'].min())
    print('AVG potassium required:', x['K'].mean())
    print('Maximum potassium required:', x['K'].max())
    print('----------------------------------------------------------')
    print('Statistic of Temperature')
    print('Minimum Temprature required:', x['temperature'].min())
    print('AVG Temperature required:', x['temperature'].mean())
    print('Maximum Teperature required:', x['temperature'].max())
    print('----------------------------------------------------------')
    print('Statistic of Humidity')
    print('Minimum Humidity required:', x['humidity'].min())
    print('AVG Humidity required:', x['humidity'].mean())
    print('Maximum Humidity required:', x['humidity'].max())
    print('----------------------------------------------------------')
    print('Statistic of ph')
    print('Minimum ph required:', x['ph'].min())
    print('AVG ph required:', x['ph'].mean())
    print('Maximum ph required:', x['ph'].max())
    print('----------------------------------------------------------')
    print('Statistic of rainfall')
    print('Minimum rainfall required:', x['rainfall'].min())
    print('AVG rainfall required:', x['rainfall'].mean())
    print('Maximum rainfall required:', x['rainfall'].max())
    print('----------------------------------------------------------')
# Out:
# interactive(children=(Dropdown(description='crops', options=('watermelon', 'pomegranate', 'mungbean', 'grapes'…

# %%
@interact

def compare (conditions = ['N', 'P','K', 'temperature', 'ph', 'humidity', 'rainfall']): 
    print("Average Value for", conditions, "is (0:.2f)".format(data[conditions].mean()))
    print('--------------------------------------------------------------------------------')
    print("Rice: ",format(data[(data['label'] == 'rice')][conditions].mean()))
    print("Black Grams: ", format(data[data[ 'label'] == 'blackgram'][conditions].mean())) 
    print("Banana: ",format(data[ (data["label"] =='banana')][conditions].mean()))
    print("Jute: ", format(data[data['label'] =='jute'][conditions].mean()))
    print("Coconut :", format(data[(data['label'] == 'coconut')][conditions].mean()))
    print("Apple ", format (data[data['label'] =='apple'][conditions].mean()))
    print("Papaya : ", format (data[(data['label'] == 'papaya')][conditions].mean()))
    print("Muskmelon ",format(data[data['label'] == 'muskmelon'][conditions].mean()))
    print("Grapes: ",format(data[(data['label'] == 'grapes')][conditions].mean()))
    print("Watermelon : ",format(data[data['label'] == 'watermelon'][conditions].mean()))
    print("Kidney Beans:",format(data[(data['label'] == 'kidneybeans')][conditions].mean()))
    print("Mung Beans: ", format (data[data['label'] =='mungbean'][conditions].mean()))
    print("Oranges:",format (data[(data["label"] =='orange')][conditions].mean()))
    print("Chick Peas ",format(data[data[ 'label'] == "chickpea"][conditions].mean())) 
    print("Lentils ",format(data[ (data[ 'label'] =='lentil')][conditions].mean()))
    print("Cotton : ",format(data[data['label'] == 'cotton'][conditions].mean()))
    print("Maize ",format(data[(data["label"]=='maize')][conditions].mean()))
    print("Maize: ",format(data[(data['label'] == 'maize')][conditions].mean()))
    print("Moth Beans: ",format (data[data[ 'label'] == 'mothbeans'][conditions].mean()))
    print("Pigeon Peas: ",format(data[ (data['label'] =='pigeonpeas')][conditions].mean()))
    print("Mango ",format(data[data['label'] == 'mango'][conditions].mean()))
    print("Pomegrnate: ",format(data[(data[ 'label'] =='pomegranate')][conditions].mean())) 
    print("Coffee ",format(data[data['label'] == 'coffee'][conditions].mean()))
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'temperature', 'ph', 'humidit…

# %%
@interact
def compare(conditions=['N','P','K', 'temperature','ph','humidity','rainfall']):
    print('crops which require greater than average',conditions,'\n')
    print(data[data[conditions]>data[conditions].mean()]['label'].unique())
    print('----------------------------------------------------')
    print('Crops which required less than avg', conditions,'\n')
    print(data[data[conditions]<= data[conditions].mean()]['label'].unique())
# Out:
# interactive(children=(Dropdown(description='conditions', options=('N', 'P', 'K', 'temperature', 'ph', 'humidit…

# %%
def plot(type=['N','P','K', 'temperature','ph','humidity','rainfall']):
    for i in range(0,7):
        plt.figure(figsize = (10,12))
        sns.displot(data[type[i]],color = 'blue', kde= True )
        plt.xlabel(type[i], fontsize = 20)
        plt.show()
plot()

# %%
from sklearn.cluster import KMeans

# %%
# removing the label column
x = data.drop(['label'], axis = 1)

#selecting all values from data
x= x.values

#checking the shape
print('Shape of x is  ', x.shape)
# Out:
# Shape of x is   (2200, 7)

# %% [markdown]
# fro unsupervised ML here is no needs of labels

# %% [markdown]
# ### finding the number of clusters

# %%
 # ploting albow chart

 plt.figure(figsize =(10,4) )
 wcss = []
 for i in range(1,11):
     km = KMeans(n_clusters= i, init = 'k-means++', max_iter= 300, random_state=0)
     km.fit(x)
     wcss.append(km.inertia_)

plt.plot(range(1,11),wcss)
plt.title(' The elbow method', fontsize =20)
plt.xlabel('No of clusters')
plt.ylabel('wcss')
plt.show()

# %%
# Performing K mean algorithm to perform clustering analysis
km= KMeans(n_clusters=4,init = "k-means++",max_iter = 300, n_init=10, random_state=0)
y_means= km.fit_predict(x)

# finding the result
a = data['label']
y_means = pd.DataFrame(y_means)
z= pd.concat([y_means , a],axis = 1)
z = z.rename(columns = {0: 'cluster'})

print('Result of k means clustering')
print('____________________________________________________________________________________')
print('Crops in first cluster', z[z['cluster']==0]['label'].unique())
print('____________________________________________________________________________________')
print('Crops in second cluster', z[z['cluster']==1]['label'].unique())
print('____________________________________________________________________________________')
print('Crops in third cluster', z[z['cluster']==2]['label'].unique())
print('____________________________________________________________________________________')
print('Crops in fourth cluster', z[z['cluster']==3]['label'].unique())
print('____________________________________________________________________________________')
# Out:
# Result of k means clustering
# ____________________________________________________________________________________
# Crops in first cluster ['maize' 'chickpea' 'kidneybeans' 'pigeonpeas' 'mothbeans' 'mungbean'
#  'blackgram' 'lentil' 'pomegranate' 'mango' 'orange' 'papaya' 'coconut']
# ____________________________________________________________________________________
# Crops in second cluster ['maize' 'banana' 'watermelon' 'muskmelon' 'papaya' 'cotton' 'coffee']
# ____________________________________________________________________________________
# Crops in third cluster ['grapes' 'apple']
# ____________________________________________________________________________________
# Crops in fourth cluster ['rice' 'pigeonpeas' 'papaya' 'coconut' 'jute' 'coffee']
# ____________________________________________________________________________________

# %% [markdown]
# These cluster based on climate and soil conditions

# %%
#implimenting predictive models that logistic regression
y = data['label']
x= data.drop(['label'], axis = 1)

# %%
# Out:
# (1760, 7)
# (440, 7)
# (1760,)
# (440,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(x)
x_scaled = scaler.transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x_scaled,y,test_size=0.2, random_state= 0)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1760, 7)
# (440, 7)
# (1760,)
# (440,)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=500)
model.fit(x_train,y_train)
y_pre = model.predict(x_test)

# %%
#lets evaluate the models performance
from sklearn.metrics import confusion_matrix,classification_report
plt.rcParams['figure.figsize']=(10,10)
cm = confusion_matrix(y_test, y_pre)
sns.heatmap(cm,annot=True,cmap='Wistia')
plt.title('Confusion Matrix for Logistic Regression', fontsize=15)
plt.show()

# %%
cr= classification_report(y_test,y_pre)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00        18
#       banana       1.00      1.00      1.00        18
#    blackgram       0.87      0.91      0.89        22
#     chickpea       1.00      1.00      1.00        23
#      coconut       1.00      1.00      1.00        15
#       coffee       1.00      1.00      1.00        17
#       cotton       0.94      1.00      0.97        16
#       grapes       1.00      1.00      1.00        18
#         jute       0.87      0.95      0.91        21
#  kidneybeans       0.95      1.00      0.98        20
#       lentil       0.82      0.82      0.82        17
#        maize       1.00      0.94      0.97        18
#        mango       1.00      1.00      1.00        21
#    mothbeans       0.95      0.84      0.89        25
#     mungbean       1.00      1.00      1.00        17
#    muskmelon       0.96      1.00      0.98        23
# ...

# %%
prediction = model.predict(np.array([[90,40,40,20,80,7,200 ]]))
print(prediction)
# Out:
# ['rice']
